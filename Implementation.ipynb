# %%
from keras.utils import to_categorical
from keras_preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
import os
import pandas as pd
import numpy as np

# %%
from keras.models import model_from_json

# %%
json_file = open("emotiondetector.json", "r")
model_json = json_file.read()
json_file.close()
model = model_from_json(model_json)
model.load_weights("emotiondetector.h5")

# %%
label = ['angry','disgust','fear','happy','neutral','sad','surprise']

# %%
def ef(image):
    img = load_img(image,grayscale =  True )
    feature = np.array(img)
    feature = feature.reshape(1,48,48,1)
    return feature/255.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = 'C:/coding internship program/.vscode/Face_Emotion_Recognition/train/angry/Training_332231.jpg'
print("original image is of angry")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# model prediction is  angry

# %%
image = 'C:/coding internship program/.vscode/Face_Emotion_Recognition/train/disgust/Training_12096769.jpg'
print("original image is of Disgust")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of Disgust
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# model prediction is  disgust

# %%
image = 'C:/coding internship program/.vscode/Face_Emotion_Recognition/train/fear/Training_1858708.jpg'
print("original image is of Fear")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of Fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# model prediction is  fear

# %%
image = 'C:/coding internship program/.vscode/Face_Emotion_Recognition/train/happy/Training_526145.jpg'
print("original image is of Happy")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of Happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# model prediction is  happy

# %%
image = 'C:/coding internship program/.vscode/Face_Emotion_Recognition/train/neutral/Training_354740.jpg'
print("original image is of neutral")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# model prediction is  neutral

# %%
image = 'C:/coding internship program/.vscode/Face_Emotion_Recognition/train/sad/Training_2615927.jpg'
print("original image is of Sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of Sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# model prediction is  sad

# %%
image = 'C:/coding internship program/.vscode/Face_Emotion_Recognition/train/surprise/Training_2046171.jpg'
print("original image is of Surprise")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of Surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# model prediction is  surprise

# %%
image = 'C:/coding internship program/.vscode/Face_Emotion_Recognition/train/disgust/Training_22784404.jpg'
print("original image is of Disgust")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of Disgust
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# model prediction is  disgust
